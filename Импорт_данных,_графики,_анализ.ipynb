# %% [markdown]
# <a href="https://colab.research.google.com/github/prog815/abscur_prediction/blob/master/%D0%98%D0%BC%D0%BF%D0%BE%D1%80%D1%82_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85%2C_%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8%2C_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Импорт данных, графики, анализ**

# %% [markdown]
# **Абсолютный курс**
#
# Енин А.В.
#
# г. Оренбург
#
# 2020 г.

# %% [markdown]
# Сайт - http://www.abscur.ru
#
# Twitter - https://twitter.com/abscurs
#
# ВКонтакте -  https://vk.com/abscur
#
# Одноклассники -  https://ok.ru/group/53547043520717
#
# FB -  https://www.facebook.com/abscur
#
# Telegram - https://t.me/AbsCur
#
# GitHub - https://github.com/prog815/abscur_prediction
#
# WhatsUp - https://chat.whatsapp.com/KrNJXAKizPxDlDSjYfdpQs
#
# Viber - https://invite.viber.com/?g2=AQB63y7Cm%2BNJK0tNZW%2F9kI00M6Wr8HuZ7XeamzN4jZCve8Aq9%2FiD3DY56Eqcf7dc

# %% [markdown]
# Есть таблица с выгрузками абсолютных курсов. Берем ее данные и в колабе анализируем. Сначала импортируем. Затем рисуем графики. Затем смотрим на статистические характеристики.

# %% [markdown]
# # Библиотеки

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Импорт данных

# %% [markdown]
# Таблица с историей абсолютных курсов: https://docs.google.com/spreadsheets/d/1_-cdNCIC6NgyRDj0zLJBaohXo-K8qCfxfDLbYq2JLhs/edit#gid=422799220

# %%
data_url = 'https://docs.google.com/spreadsheets/d/1_-cdNCIC6NgyRDj0zLJBaohXo-K8qCfxfDLbYq2JLhs/export?format=csv&id=1_-cdNCIC6NgyRDj0zLJBaohXo-K8qCfxfDLbYq2JLhs&gid=422799220'
abs_data = pd.read_csv(data_url,decimal=',',parse_dates=True,index_col=0)
# print(abs_data.info())
abs_data
# Out:
#                   aud        cad       hkd  ...       twd       uah       vnd
# дата                                        ...
# 2016-09-03  12.235250  12.427320  2.081908  ...  0.509440  0.603616  0.000724
# 2016-09-04  12.220960  12.436600  2.081939  ...  0.509448  0.603625  0.000724
# 2016-09-05  12.233270  12.480690  2.080509  ...  0.513835  0.603175  0.000723
# 2016-09-06  12.318520  12.477080  2.066407  ...  0.514411  0.596852  0.000719
# 2016-09-07  12.294740  12.435980  2.065948  ...  0.512819  0.600339  0.000718
# ...               ...        ...       ...  ...       ...       ...       ...
# 2020-03-12  11.754319  13.349684  2.375353  ...  0.612492  0.713272  0.000797
# 2020-03-13  11.566648  13.378534  2.388942  ...  0.615573  0.710950  0.000800
# 2020-03-14  11.496211  13.469620  2.391430  ...  0.616214  0.711690  0.000801
# 2020-03-15  11.459272  13.441513  2.397076  ...  0.617796  0.713026  0.000803
# 2020-03-16  11.520853  13.442386  2.408247  ...  0.619722  0.706174  0.000805
#
# [1291 rows x 45 columns]

# %% [markdown]
# # Вывод графика

# %%
samp_cur = np.random.choice(abs_data.columns) 
abs_data[samp_cur].plot()
plt.title('Абсолютный курс '+samp_cur.upper())
plt.grid()

# %% [markdown]
# # Статистические характеристики

# %%
abs_data.describe()
# Out:
#                aud          cad  ...          uah          vnd
# count  1291.000000  1291.000000  ...  1291.000000  1291.000000
# mean     12.433430    12.954041  ...     0.645088     0.000739
# std       0.227775     0.419758  ...     0.044971     0.000022
# min      11.459272    12.042180  ...     0.550191     0.000695
# 25%      12.269281    12.689050  ...     0.617434     0.000721
# 50%      12.430540    12.948320  ...     0.629587     0.000742
# 75%      12.594550    13.310475  ...     0.662466     0.000754
# max      12.936410    13.671369  ...     0.761982     0.000805
#
# [8 rows x 45 columns]
