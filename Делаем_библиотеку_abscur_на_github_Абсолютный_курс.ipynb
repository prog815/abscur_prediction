# %% [markdown]
# <a href="https://colab.research.google.com/github/prog815/abscur_prediction/blob/master/%D0%94%D0%B5%D0%BB%D0%B0%D0%B5%D0%BC_%D0%B1%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D1%83_abscur_%D0%BD%D0%B0_github_%D0%90%D0%B1%D1%81%D0%BE%D0%BB%D1%8E%D1%82%D0%BD%D1%8B%D0%B9_%D0%BA%D1%83%D1%80%D1%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Делаем библиотеку abscur на github. Абсолютный курс**

# %% [markdown]
# **Абсолютный курс**
#
# Енин А.В.
#
# г. Оренбург
#
# 24.04.2020 г.

# %% [markdown]
# Сайт - http://www.abscur.ru
#
# Twitter - https://twitter.com/abscurs
#
# ВКонтакте -  https://vk.com/abscur
#
# Одноклассники -  https://ok.ru/group/53547043520717
#
# FB -  https://www.facebook.com/abscur
#
# Telegram - https://t.me/AbsCur
#
# GitHub - https://github.com/prog815/abscur_prediction
#
# WhatsUp - https://chat.whatsapp.com/KrNJXAKizPxDlDSjYfdpQs
#
# Viber - https://invite.viber.com/?g2=AQB63y7Cm%2BNJK0tNZW%2F9kI00M6Wr8HuZ7XeamzN4jZCve8Aq9%2FiD3DY56Eqcf7dc

# %% [markdown]
# Предсказываем будущий знак изменения с помощью библиотеки Xgboost: https://github.com/dmlc/xgboost/blob/master/demo/guide-python/sklearn_examples.py

# %% [markdown]
# # Импорт данных

# %% [markdown]
# Таблица с историей абсолютных курсов: https://docs.google.com/spreadsheets/d/1_-cdNCIC6NgyRDj0zLJBaohXo-K8qCfxfDLbYq2JLhs/edit#gid=422799220

# %%
! wget -O abscur.py https://github.com/prog815/abscur_prediction/raw/master/abscur.py 
import abscur
# Out:
# --2020-04-24 06:10:30--  https://github.com/prog815/abscur_prediction/raw/master/abscur.py
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/prog815/abscur_prediction/master/abscur.py [following]
# --2020-04-24 06:10:30--  https://raw.githubusercontent.com/prog815/abscur_prediction/master/abscur.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 532 [text/plain]
# Saving to: ‘abscur.py’
#
# abscur.py           100%[===================>]     532  --.-KB/s    in 0s
#
# 2020-04-24 06:10:30 (24.4 MB/s) - ‘abscur.py’ saved [532/532]

# %%
import sys
if 'abscur' in sys.modules:
    del sys.modules['abscur']
import abscur

# %%
abscur.get_data()
# Out:
#                   aud        cad       hkd  ...       twd       uah       vnd
# дата                                        ...
# 2016-09-03  12.235250  12.427320  2.081908  ...  0.509440  0.603616  0.000724
# 2016-09-04  12.220960  12.436600  2.081939  ...  0.509448  0.603625  0.000724
# 2016-09-05  12.233270  12.480690  2.080509  ...  0.513835  0.603175  0.000723
# 2016-09-06  12.318520  12.477080  2.066407  ...  0.514411  0.596852  0.000719
# 2016-09-07  12.294740  12.435980  2.065948  ...  0.512819  0.600339  0.000718
# ...               ...        ...       ...  ...       ...       ...       ...
# 2020-04-10  12.006637  13.551712  2.442125  ...  0.630059  0.695986  0.000807
# 2020-04-11  12.008962  13.564640  2.441655  ...  0.629938  0.695852  0.000807
# 2020-04-12  12.017066  13.575673  2.440801  ...  0.629907  0.695610  0.000807
# 2020-04-13  12.052413  13.602220  2.443468  ...  0.629813  0.699588  0.000808
# ...
